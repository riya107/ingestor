# %%
import os

# %%
def find_folder(directory, target_folder):
    for root, dirs, files in os.walk(directory):
        if target_folder in dirs:
            return os.path.join(root, target_folder)
    return None

# %%
# Specify the path to the directory you want to search
directory = "data"

# Specify the name of the folder you want to find
target_folder = input("Enter the name of the folder you want to find: ")

# Call the find_folder() function
result = find_folder(directory, target_folder)

# Check if the folder was found
if result:
    print("Found the folder:", result)
else:
    print("Unable to find the folder within the specified directory.")
# Out:
# Found the folder: data\ENGINEERING

# %%
if result:
    print("Found the 'ENGINEERING' folder:", result)
    print("Extracting the resumes from the 'ENGINEERING' folder...")
    
    # Specify the path to the folder containing the text files
    resume_folder = result
    
    # List to store the names of the resumes
    resume_names = []
    
    # List to store the content of the resumes
    resumes = []
    
    # Iterate over the files in the resume folder
    for filename in os.listdir(resume_folder):
        if filename.endswith('.txt'):
            with open(os.path.join(resume_folder, filename), 'r') as f:
                resume = f.read()
                # Preprocess the resume if needed
                resumes.append(resume)
                resume_names.append(filename)
    
    # Print the resume names and their content
    # for name, resume in zip(resume_names, resumes):
    #     # print("Resume name:", name)
    #     # print("Resume content:", resume)
    print("Extracted {} resumes from the 'ENGINEERING' folder.".format(len(resumes)))
else:
    print("Unable to find the 'ENGINEERING' folder within the 'data' directory.")
# Out:
# Found the 'ENGINEERING' folder: data\ENGINEERING
# Extracting the resumes from the 'ENGINEERING' folder...
# Extracted 185 resumes from the 'ENGINEERING' folder.

# %%
import os
import shutil
import time
import logging
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\sudhir
# [nltk_data]     Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\sudhir
# [nltk_data]     Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import numpy as np

# %%
dataset = np.load('embeddings/cv1.config.npy')

# %%
import datetime

# %%
timestamp = datetime.datetime.now().strftime("%H:%M:%S/%d:%m/%Y")
print(timestamp)
# Out:
# 12:07:33/31:05/2023

# %%
logging.basicConfig(filename=f"processing_logs_{timestamp}.log", level=logging.INFO, format='%(asctime)s - %(message)s')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 logging.basicConfig(filename=f"processing_logs_{timestamp}.log", level=logging.INFO, format='%(asctime)s - %(message)s')
#
# NameError: name 'logging' is not defined

# %%
print(timestamp)
# Out:
# 20230531115957

# %%
dataset
# Out:
# array([ 1.39479255e-02,  2.98456490e-01,  5.00610054e-01, -1.95649534e-01,
#         3.38876456e-01, -7.14865625e-02,  1.88351989e-01,  1.75316855e-01,
#        -2.54170060e-01, -2.03624025e-01,  2.24960260e-02, -6.27631024e-02,
#        -8.28469694e-02,  2.67633080e-01,  8.66217315e-02,  1.81538478e-01,
#         3.06252301e-01, -8.41981545e-02,  1.42542664e-02,  3.10214967e-01,
#         2.54200369e-01,  1.02772657e-02,  8.66414383e-02,  2.71475136e-01,
#         2.91327864e-01, -5.11144921e-02, -3.57190259e-02, -3.73962219e-04,
#        -2.25967571e-01, -3.56194004e-02,  1.33517876e-01, -1.00280337e-01,
#         1.76230282e-01, -1.71689525e-01,  1.57437339e-01,  3.66845797e-03,
#        -2.42917269e-01,  9.08144712e-02,  2.90305540e-02,  2.67234296e-01,
#        -1.94368899e-01, -3.86144221e-01,  7.36320168e-02,  1.03346415e-01,
#        -2.19244808e-01, -1.33335277e-01, -2.96572000e-01, -3.20750773e-02,
# ...

# %%
def _preprocess_text(self, text):
    # Convert text to lowercase
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove special characters
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)

    # Tokenize the text into individual words
    tokens = nltk.word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Lemmatize words
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # Join the tokens back into a single string
    preprocessed_text = ' '.join(tokens)
    print(preprocessed_text)
    return preprocessed_text

# %%
print(_preprocess_text(text)
# Out:
#   Cell In[14], line 1
#     print(_preprocess_text(text)
#                                 ^
# SyntaxError: incomplete input
